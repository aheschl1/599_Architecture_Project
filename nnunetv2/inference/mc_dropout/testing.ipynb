# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/andrew.heschl/Dataset/output_21/b0da0c80-0f9d-11ee-8b03-20040ff053bc"
prob = np.load(f"{path}/case_00002_0.npz")['probabilities']   #Must read the key for both
img = np.load(f"{path}/case_00002_original.npz")['image']

# %%
plt.imshow(img[0][100])
